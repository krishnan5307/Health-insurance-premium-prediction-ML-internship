# %%
import numpy,pandas as pd,matplotlib.pyplot as plt,seaborn as sns

# %%
os.getcwd()
# Out:
# 'c:\\Users\\krish\\Health-insurance-premium-prediction-ML-internship\\notebook'

# %%
os.chdir("c:\\Users\\krish\\Health-insurance-premium-prediction-ML-internship\\notebook")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\krish\\Health-insurance-premium-prediction-ML-internship\\notebook'

# %%
df= pd.read_csv(r"c:\\Users\\krish\\Health-insurance-premium-prediction-ML-internship\\dataset\\dataset.csv", sep=",")

# %%
df.head()
# Out:
#    age  expenses   bmi     region  children   sex smoker
# 0   25   2137.65  25.7  southeast         0  male     no
# 1   45   8605.36  20.4  southeast         3  male     no
# 2   51   8782.47  25.4  southwest         0  male     no
# 3   31   3857.76  30.9  northeast         0  male     no
# 4   18   1704.57  23.0  northeast         0  male     no

# %%
df["region"].unique()
# Out:
# array(['southeast', 'southwest', 'northeast', 'northwest'], dtype=object)

# %%
print(df.shape)
# Out:
# (1337, 7)

# %%
df.isnull().sum()
# Out:
# age         0
# expenses    0
# bmi         0
# region      0
# children    0
# sex         0
# smoker      0
# dtype: int64

# %%
sns.boxplot(df['expenses'])
# Out:
# c:\Users\krish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='expenses'>

# %%
numerical_features=[feature for feature in df.columns if df[feature].dtypes!='O']

# %%
numerical_features
# Out:
# ['age', 'expenses', 'bmi', 'children']

# %%
cat_features=[feature for feature in df.columns if df[feature].dtypes=='O']

# %%
cat_features
# Out:
# ['region', 'sex', 'smoker']

# %%
data= df.copy()
for feature in numerical_features[0:3]:
    data.groupby(feature)['expenses'].median().plot().bar
    plt.xlabel(feature)
    plt.ylabel('expenses')
    plt.title(f'{feature} vs premium')
    plt.show()

# %%
sns.histplot(data['expenses'],kde=True)
# Out:
# <AxesSubplot:xlabel='expenses', ylabel='Count'>

# %%
##Categorical variables

# %%
data=df.copy()
for feature in cat_features:
    data.groupby(feature)['expenses'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('expenses')
    plt.title(feature)
    plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
